# %% [markdown]
# # <font size = 8 color ='E1554F'>Diabetes Dataset</font>
#
# **Team's name:** *AI's Daemons*\
# **Team's members:**
# - Cristobal Eleazar Meza (A01661792)
# - Ricardo Campos Luna (A01656898)
# - Diego Esteban Zepeda Ceballos (A01026512)
#
#
# \
# This dataset is originally from Bradley Efron, Trevor Hastie, Iain Johnstone, and Robert Tibshirani's study, "Least Angle Regression." It's one of the standard datasets available in the scikit-learn library.
#
# The diabetes dataset consists of ten baseline variables: age, sex, body mass index (BMI), average blood pressure, and six blood serum measurements. The target variable is a quantitative measure of disease progression one year after baseline.
#
# Attributes/Features:
#
# * <font color ='E1554F'>**age:**</font> Age in years.
# * <font color ='E1554F'>**sex:**</font> A binary variable indicating gender.
# * <font color ='E1554F'>**bmi:**</font> Body mass index.
# * <font color ='E1554F'>**bp:**</font> Average blood pressure.
# * <font color ='E1554F'>**s1-s6:**</font> Six blood serum measurements.
#
# The target variable is a quantitative measure of disease progression one year after the baseline. It's a continuous value that provides an indication of how much the disease has progressed.
#
# The primary objective when using this dataset in machine learning is to predict the disease progression (the target) based on the given features. Regression techniques are typically applied to this dataset due to the continuous nature of the target variable.

# %% [markdown]
# ### Import libraries
# Hint: Consider to import pandas, sklearn, seaborn and matplotlib

# %%
# Your code (5 point)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_diabetes

# %% [markdown]
# ### Load the Diabetes dataset into a Pandas dataframe and create a scatter plot of Age vs Disease Progression.

# %%
# Load diabetes dataset and cast to dataframe
diabetes_ds = load_diabetes()
diabetes_df = pd.DataFrame(diabetes_ds.data, columns = diabetes_ds.feature_names)

# %%
# Show diabetes
diabetes_df['target'] = diabetes_ds.target
diabetes_df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6  target
# ...

# %%
# Scatter plot of Age vs. Disease Progression
plt.figure(figsize = (10, 6))
plt.title('Age vs. Diabetes Progression')
plt.xlabel('Age')
plt.ylabel('Diabetes Progression')
sns.set_theme(style = 'darkgrid')
sns.scatterplot(data = diabetes_df,
                x = 'age',
                y = 'target')
plt.show()


# seems very low relation (very separated, no pattern or cluster seems to tend to form)

# %% [markdown]
# ### Compute and show statistics for 'age.'
# Hint: Consider all statistical values shown in class.

# %%
# Age statistics
diabetes_df['age'].describe()

# as seen on the graph before
# very high std
# points are very separeted
# Out:
# count    4.420000e+02
# mean    -2.511817e-19
# std      4.761905e-02
# min     -1.072256e-01
# 25%     -3.729927e-02
# 50%      5.383060e-03
# 75%      3.807591e-02
# max      1.107267e-01
# Name: age, dtype: float64

# %% [markdown]
# ### Compute and show statistics for 'age.'
# Hint: Consider all statistical values shown in class.

# %%
# Your code (10 points)
diabetes_df['age'].describe()
# Out:
# count    4.420000e+02
# mean    -2.511817e-19
# std      4.761905e-02
# min     -1.072256e-01
# 25%     -3.729927e-02
# 50%      5.383060e-03
# 75%      3.807591e-02
# max      1.107267e-01
# Name: age, dtype: float64

# %% [markdown]
# ### Show the IQR.
# Hint: Use a boxplot

# %%
# Your code (5 point)
quatiles = diabetes_df['age'].quantile([0.25, 0.5, 0.75])
iqr = quatiles[0.75] - quatiles[0.25]

plt.figure(figsize = (2, 4))
plt.title('Boxplot of Age')
plt.xlabel(f'IQR: {iqr:0.3f}')
sns.boxplot(diabetes_df['age'],
            orient = 'v')
plt.show()

# %% [markdown]
# ### Compute the correlation matrix.
# Use all the features in the dataset.

# %%
# Your code (5 point)
# heatmap
plt.figure(figsize = (10, 8))
plt.title('Correlation Matrix')
selected_columns = ['age',	'sex',	'bmi',	'bp',	's1',	's2',	's3',	's4',	's5',	's6',	'target']
column_x = diabetes_df[selected_columns]
corr = column_x.corr()
sns.heatmap(corr, annot = True)
plt.show()

# %% [markdown]
# ### According to the results, What would you say about the values ​​obtained from the statistical analysis and the correlation matrix?? Put your response in the following cell. (10 points)

# %% [markdown]
# The target (diabetes progression) is more correlated with:
#
# 1. 0.59 Body Mass Index
# 2. 0.57 s5-blood serum
# 3. 0.44 Blood Pressure
# 4. 0.43 s4-blood serum
# 5. 0.39 s3 blood serum
# 6. 0.38 s6-blood serum
# 7. 0.21 s1-clood serum
# 8. 0.19 Age
# 9. 0.17 s2-blood serum
# 10. 0.043 Sex

# %%
# Graph for the conclutions
plt.figure(figsize = (7, 4))
plt.title('Variables more correlated with diabetes progression')
plt.xlabel('Variable (feature)')
plt.ylabel('Correlation coefficient [-1, 1]')

sns.set_theme(style = 'darkgrid')

ax = sns.barplot(corr['target'].sort_values(ascending = False)[1:], palette = 'viridis')
ax.axhline(y = 0.5, color = 'red', linestyle = '--')
ax.axhline(y = -0.35, color = 'green', linestyle = '--')
ax.margins(y = 0.1)

plt.show()
# Out:
# <ipython-input-104-b9b5242ff327>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(corr['target'].sort_values(ascending = False)[1:], palette = 'viridis')

# %% [markdown]
# ## <font color ='E1554F'>**Conclusions:**</font>
#
# So, regarding <font color ='E1554F'>**Age**</font> as a first point of comparison, it seems to be just a <font color ='E1554F'>**slight factor**</font> towards <font color ='E1554F'>**diabetes progression**</font>.
#
# Everyone seems to be able to present it regardless of age.
#
# However, we should be worrying if our <font color ='E1554F'>**body mass index (BMI)**</font>, some <font color ='E1554F'>**serums**</font> and <font color ='E1554F'>**blood pressure (BP)**</font> seem to be abnormal.
#
# It appears that <font color ='E1554F'>**blood serum-3 (s3)**</font> sighlt helps to slow down the diabetes progression, it maybe could be the key for treatment that control the disease.
